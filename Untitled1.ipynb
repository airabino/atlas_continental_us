# %%
import warnings
warnings.filterwarnings("ignore")

import os
import sys
import time
import json
import momepy

import numpy as np
import pandas as pd
import geopandas as gpd
import networkx as nx
import matplotlib.pyplot as plt

import src
from src.reload import deep_reload

# %%
graph = src.graph.graph_from_json('Outputs/California/reduced_atlas.json')

# %%
fig, ax = plt.subplots(1, 1, figsize = (8, 6))

kw = {
    'show_links': True,
    'node_field': 'state',
    'scatter': {
        's': .75,
        'ec': 'none',
        # 'fc': 'k',
        'zorder': 0,
    },
    'plot': {
        'color': 'k',
        'lw': .5,
    },
}

src.figures.plot_graph(graph, ax = ax, **kw)

kw = {
    'facecolor': 'whitesmoke',
}

ax.set(**kw)

kw = {
    'ls': '--',
}

ax.grid(**kw)
